# %%
import numpy as np
import matplotlib.pyplot as plt

N=4

fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(4, 4))
ax0 = axes

# small, medium, large, xlarge
# 1, 2, 4, 8 vcpus

aws_map = [310480, 129941, 57483,38653]
aws_reduce = [28298, 10214, 4518,2834]
aws_pmem = [2134048768, 2524913664, 2783719424,2815410176]
aws_vmem = [7037362176, 7430656000, 7399215104,7708618752]
aws_heap = [1398906880, 1859125248, 2214592512,2214592512]

aws_gctime = [5120, 671, 645,416]
aws_cpu = [4830, 3840, 4020,4500]
aws_coremark = [13184.784758,27157.308711,55180.024831,85892.205282]

azure_map = [281416,115800,60871,33613]
azure_reduce = [25441,9213,4416,2993]
azure_pmem = [2299543552,2552201216,2840489984,2880548864]
azure_vmem = [7590567936,7992373248,7957135360,8245231616]
azure_heap = [1623457792,1866465280,2214592512,2214592512]
azure_gctime = [3717,426,1029,320]
azure_cpu = [4580,3670,3890,4180]
azure_coremark = [12623.074981,27419.797094,54384.772264,97626.456770]

gce_map = [303206, 215704, 87781,43921]
gce_reduce = [29206, 18122, 6805,3606]
gce_pmem = [2299277312, 2611683328, 2823540736,2831941632]
gce_vmem = [7589281792, 7985856512, 8070135808,8224985088]
gce_heap = [1640235008, 2020081664, 2214592512,2183659520]
gce_gctime = [4453, 1295, 776,298]
gce_cpu = [4750, 6670, 5980,5950]
gce_coremark = [13116.474292, 18799.642807, 39876.383212, 83809.124718]

ind = np.arange(N)    # the x locations for the groups
width = 0.15       # the width of the bars: can also be len(x) sequence

aws_mr = [x + y for x, y in zip(aws_reduce, aws_map)]
gce_mr = [x + y for x, y in zip(gce_reduce, gce_map)]
azure_mr = [x + y for x, y in zip(azure_reduce, azure_map)]
aws_mr0 = ax0.bar(ind+.06, aws_mr, width, color='r')

ax0.set_label('Number of requests')
ax0.set_ylabel('milliseconds')
ax0.set_title('MapReduce Time')

plt.xticks(ind + width, ['small','medium','large','xlarge'])
ax0.set_title('MapReduce Pi Example by Server Size')
ax0.legend(handles=[aws_mr0[0]],labels=["AWS"],bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

fig.tight_layout()

plt.show()

# %%
N=4

fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(4, 4))
ax0 = axes

aws_mr = [x + y for x, y in zip(aws_reduce, aws_map)]
gce_mr = [x + y for x, y in zip(gce_reduce, gce_map)]
azure_mr = [x + y for x, y in zip(azure_reduce, azure_map)]
aws_mr0 = ax0.bar(ind+.06, aws_mr, width, color='r')
gce_mr0 = ax0.bar(ind+.06+width, gce_mr, width, color='y')

ax0.set_label('Number of requests')
ax0.set_ylabel('milliseconds')
ax0.set_title('MapReduce Time')
plt.xticks(ind + width, ['small','medium','large','xlarge'])

ax0.set_title('MapReduce Pi Example by Server Size')
ax0.legend(handles=[aws_mr0[0],gce_mr0[0]],labels=["AWS",'GCE'],bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

fig.tight_layout()

plt.show()

# %%
N=4

fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(4, 4))
ax0 = axes



aws_mr = [x + y for x, y in zip(aws_reduce, aws_map)]
gce_mr = [x + y for x, y in zip(gce_reduce, gce_map)]
azure_mr = [x + y for x, y in zip(azure_reduce, azure_map)]
aws_mr0 = ax0.bar(ind+.06, aws_mr, width, color='r')
gce_mr0 = ax0.bar(ind+.06+width, gce_mr, width, color='y')
azure_mr0 = ax0.bar(ind+.06+(width*2), azure_mr, width, color='b')

ax0.set_label('Number of requests')
ax0.set_ylabel('milliseconds')
ax0.set_title('MapReduce Time')
plt.xticks(ind + 0.1+width, ['small','medium','large','xlarge'])

ax0.set_title('MapReduce Pi Example by Server Size')
ax0.legend(handles=[aws_mr0[0],gce_mr0[0],azure_mr0[0]],labels=["AWS",'GCE','AZURE'],bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

fig.tight_layout()

plt.show()

# %%
N=4

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(8, 4))
ax0, ax1 = axes.flat

aws_coremark = [13184.784758,27157.308711,55180.024831,85892.205282]

azure_map = [281416,115800,60871,33613]
azure_reduce = [25441,9213,4416,2993]
azure_pmem = [2299543552,2552201216,2840489984,2880548864]
azure_vmem = [7590567936,7992373248,7957135360,8245231616]
azure_heap = [1623457792,1866465280,2214592512,2214592512]
azure_gctime = [3717,426,1029,320]
azure_cpu = [4580,3670,3890,4180]
azure_coremark = [12623.074981,27419.797094,54384.772264,97626.456770]

gce_map = [303206, 215704, 87781,43921]
gce_reduce = [29206, 18122, 6805,3606]
gce_pmem = [2299277312, 2611683328, 2823540736,2831941632]
gce_vmem = [7589281792, 7985856512, 8070135808,8224985088]
gce_heap = [1640235008, 2020081664, 2214592512,2183659520]
gce_gctime = [4453, 1295, 776,298]
gce_cpu = [4750, 6670, 5980,5950]
gce_coremark = [13116.474292, 18799.642807, 39876.383212, 83809.124718]

aws_mr = [x + y for x, y in zip(aws_reduce, aws_map)]
gce_mr = [x + y for x, y in zip(gce_reduce, gce_map)]
azure_mr = [x + y for x, y in zip(azure_reduce, azure_map)]
aws_mr0 = ax0.bar(ind, aws_mr, width, color='r')
gce_mr0 = ax0.bar(ind+width, gce_mr, width, color='y')
azure_mr0 = ax0.bar(ind+(width*2), azure_mr, width, color='b')

aws_coremark = ax1.bar(ind, aws_coremark, width, color='r')
gce_coremark = ax1.bar(ind+width, gce_coremark, width, color='y')
azure_coremark = ax1.bar(ind+(width*2), azure_coremark, width, color='b')

ax0.set_label('Number of requests')
ax0.set_ylabel('milliseconds')
ax1.set_ylabel('CoreMark Score')
for x in axes:
    plt.sca(x)
    plt.xticks(ind + width, ['small','medium','large','xlarge'])

ax0.set_title('MapReduce Pi Example by Server Size')
ax1.set_title('CPU Benchmark Score by Server Size')

ax1.legend((aws_coremark[0], gce_coremark[0],azure_coremark[0]), ('AWS', 'GCE', 'AZURE'),bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
fig.tight_layout()
plt.show()
